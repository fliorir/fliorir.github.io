# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jul 25 08:00:37 2016

@author: krasin
"""

import pandas as pd
reportFile = "GoogleBooksTrafficReport_2017_03.csv"
metaFile = "id_table.csv"

book_report = pd.read_csv(reportFile, sep = '\t', encoding='utf-16')
book_id = pd.read_csv(metaFile, sep = '\t', header=None, encoding='utf-8')

book_report.describe()

book_report.columns

def seriesToInt(num):
    num = num.str.replace(u'\xa0', '').astype(int)
    return num
    
 
book_report['Book Visits (BV)'] = seriesToInt(book_report['Book Visits (BV)'])
book_report['BV with Pages Viewed'] = seriesToInt(book_report['BV with Pages Viewed'])
book_report['Pages Viewed'] = seriesToInt(book_report['Pages Viewed'])

# %%
book_report.replace(u'Пiсня про людину / Песен за човека', 
                    u'Песен за човека / Пiсня про людину',
                   inplace=True)
book_report.replace(u'В родината на Орфей', u'В родината на Орфей / На родине Орфея', inplace=True)
book_report.tail()
# Out:
#               isbn                                              title     BV  \
# 106  9789548226967  Основи на счетоводството и счетоводство на стр...  42742
# 107  9789548226974                                   Отвъд огледалото   1924
# 108  9789548226981               Газирана ода за страната на облаците   3732
# 109  9789548226998                                            Тунелът   3086
# 110  9789663726700              В родината на Орфей / На родине Орфея     94
#
#      bookVisits  clicks  clicks2   ctr  pagesViewed
# 106       40943     153      110  0,3%       638233
# 107        1748      26       14  0,7%        39015
# 108        3556      24       22  0,6%        46428
# 109        2782     103       72  2,3%       179623
# 110          94       0        0  0,0%          922

# %%
#initial_columns = book_report.columns
book_report.columns = ['isbn', 'title', 'BV', 'bookVisits', 'clicks', 'clicks2', 'ctr', 'pagesViewed']
book_report.tail()
# Out:
#               isbn                                              title     BV  \
# 106  9789548226967  Основи на счетоводството и счетоводство на стр...  42742
# 107  9789548226974                                   Отвъд огледалото   1924
# 108  9789548226981               Газирана ода за страната на облаците   3732
# 109  9789548226998                                            Тунелът   3086
# 110  9789663726700              В родината на Орфей / На родине Орфея     94
#
#      bookVisits  clicks  clicks2   ctr  pagesViewed
# 106       40943     153      110  0,3%       638233
# 107        1748      26       14  0,7%        39015
# 108        3556      24       22  0,6%        46428
# 109        2782     103       72  2,3%       179623
# 110          94       0        0  0,0%          922

# %%
book_id.columns = ['seqN','id', 'title', 'authors', 'date_print', 'date_ebook']
book_id.tail()
# Out:
#      seqN               id                                  title  \
# 102   103  id=URqAAwAAQBAJ      Мениджмънт на стреса в медицината
# 103   104  id=EWRnBgAAQBAJ                          План Амнезия+
# 104   105  id=e1HTCwAAQBAJ                      Откраднати илюзии
# 105   106  id=MC-yDAAAQBAJ     Песен за човека / Пiсня про людину
# 106   107  id=YMFlDQAAQBAJ  В родината на Орфей / На родине Орфея
#
#                  authors  date_print  date_ebook
# 102    на Елиа Георгиева  07.05.2014  05.05.2014
# 103     на Иван Мешинков  15.02.2015  27.01.2015
# 104  на Веселка Стойнева  21.03.2016  15.05.2016
# 105   на Никола Вапцаров  10.06.2016  12.07.2016
# 106   на Сергей Шелковий  08.08.2016  12.10.2016

# %%
b = pd.merge(book_id, book_report, how='inner', on=None,
         left_on='title', right_on='title',
      left_index=False, right_index=False, sort=False,
      copy=True, indicator=False)
b
# Out:
#      seqN               id                                              title  \
# 0       1  id=uA6tGoK6RKoC                                            Тунелът
# 1       2  id=AxzRmIQjCbgC                                      Любов на живо
# 2       3  id=8iF_9Q-yi4cC                              Лабиринтът, том първи
# 3       4  id=mzROsaIj_DAC               Газирана ода за страната на облаците
# 4       5  id=zJywHiadprsC                              Лабиринтът, том втори
# 5       6  id=rQs-IgS2XTMC                                   Отвъд огледалото
# 6       7  id=O9_yWEui8NwC  Waste Reduction and Minimization in Mining, Or...
# 7       8  id=Kgsv-_UMgsIC                                   Таблетка шепотин
# 8       9  id=fJ_ZLgxViiAC                                       Врата за ада
# 9      10  id=8Q9fG8S_XfgC                                          Империята
# 10     11  id=9hmiShsGbPQC                                    CASE технологии
# 11     12  id=iSJriizWO3AC                                      Летален изход
# 12     13  id=nV-Eq8WhwSwC                              Призрачната колесница
# 13     14  id=zjigzFlYpJ4C                                    Данайски дарове
# 14     15  id=dU6N8zVzrbkC                                 Тракийският конник
# 15     16  id=klAHJTFkpK0C                      Вампирът от замъка на Дракула
# 16     17  id=2-Jmsv_TKpEC                    Преди и сега – равно на всякога
# 17     18  id=ruu5i6BQ1LYC                   Медиацията и гражданският процес
# 18     19  id=DO3QzLfoXxYC                                    Нежна революция
# 19     20  id=33x75OaF368C                                   На крачка от рая
# 20     21  id=Pahmj4-oFWgC                                  Опасният свещеник
# 21     22  id=QmCA5qLTP_sC                                    Невчесани мисли
# 22     80  id=WQdNpppXIgoC                                    Невчесани мисли
# 23     23  id=sn0L9rJYitYC                                           Без срам
# 24     24  id=-jBHCK7cak4C                               Ключ за горната земя
# 25     25  id=jez7x7CzCVoC                                        Смешна тъга
# 26     26  id=TAmZdFR9tgEC                                  Желю в карикатури
# 27     27  id=vONoEahf7_EC                               Когато отмине студът
# 28     28  id=Yl2pKAwggL4C                                             Сезони
# 29     29  id=fhxh2COMVIsC                                    Безсезонна жена
# ..    ...              ...                                                ...
# 77     77  id=uCC9M0bBDg4C  Основи на счетоводството и счетоводство на стр...
# 78     78  id=3uEfR0bUDMQC                                   Пет минути любов
# 79     79  id=2N9aMKnRApcC                                 Вицове за политици
# 80     81  id=Ld6gPnfN-tsC                                    Второгласен път
# 81     82  id=RY5r8uUl4csC                                    Безплътна броня
# 82     83  id=xgAN9GYXaiEC                                 Място под слънцето
# 83     84  id=RUC07ls10S4C                            Българските книжни пари
# 84     85  id=zYnFSIn1HxoC             Ергосфера или лапидариум на феномените
# 85     86  id=mGhyhpZOggIC                              Двустишия на Красимир
# 86     87  id=vfsALCGhYMMC                                        Росни капки
# 87     88  id=Ee69CL4wJ-kC                                     Любовна лирика
# 88     89  id=pbXneO3jBVcC                        Второто разпятие на Христос
# 89     90  id=qfsByWtzO90C                          Ръкопис, който съществува
# 90     91  id=ioCLetyDPtAC                                  Вицове за лордове
# 91     92  id=UEZaIJ92YmMC                                           Цветница
# 92     93  id=AYNVLjKUymEC                                        Lepidoptera
# 93     94  id=_okzOJd7nnIC                                       Фатален срок
# 94     95  id=9_kaTrCsgWoC                                     Закъсняла обич
# 95     96  id=YuZ4pIKy0DcC                        Притча за пшениченото зърно
# 96     97  id=7YlT6N0kfLAC                                       Жадни миражи
# 97     98  id=OfTJEJpaJiIC                                     Очите на дъжда
# 98     99  id=Wgcqfex85TAC                                            Моливия
# 99    100  id=F0HDTWT_LgwC                          Поговорим о жизни и любви
# 100   101  id=TP2SAAP15qcC  Друвосек. Одисеята на Георги Ганев в Съветския...
# 101   102  id=Dcwum5tyoowC                                 Животът продължава
# 1                29.09.2008  9789544100025  13069       11581      36
# 2                25.07.2007  9789548226899  12003       11735      42
# 3                24.07.2008  9789548226981   3732        3556      24
# 4                08.12.2007  9789548226936   3853        3701      20
# 5                03.06.2008  9789548226974   1924        1748      26
# 6                06.08.2005  9789548226516   1841        1502      36
# 7                15.12.2008  9789544100018   1645         905       4
# 8                22.01.2009  9789544100032   6898        6665      35
# 9                02.02.2009  9789548226264   8879        8439      36
# 10               09.02.2009  9789544100049   3670        3447      38
# 11               12.03.2009  9789548226387    789         553       0
# 12               12.03.2009  9789548226103   2768        1897      10
# 13               12.03.2009  9789548226554    674         515       1
# 14   17.03.2009, прекъснато  9789548226905   1682        1060       5
# 15               17.03.2009  9789548226219   2889        2444      15
# 16               17.03.2009  9789548226448   4361        3385       2
# 17               17.03.2009  9789548226783   3773        3581      21
# 18               18.03.2009  9789548226530   1662        1490      12
# 19               18.03.2009  9789548226486   2179        1543       4
# 20               18.03.2009  9789548226745   1024         900       0
# 21               23.04.2009  9789548226769   8099        6682      21
# 22               10.09.2009  9789548226769   8099        6682      21
# 23               24.04.2009  9789548226929   1019         738       1
# 24               24.04.2009  9789548226028   1214         897       0
# 25               27.04.2009  9789548226721   8634        8342      15
# 26               27.04.2009  9789548226042   1972        1828       2
# 27               18.05.2009  9789548226882   1514         630       2
# 28               18.05.2009  9789544100094   3795        2810      17
# 29               10.06.2009  9789548226141   1472        1002       4
# ..                      ...            ...    ...         ...     ...
# 77               01.09.2009  9789548226967  42742       40943     153
# 78               06.09.2009  9789548226035   1074         721       1
# 79               08.09.2009  9789548226349   2896        2392       3
# 80               10.09.2009  9789548226110    755         376       2
# 81               10.09.2009  9789548226608   1792         621       1
# 82               11.09.2009  9789548226547   4052        3802       3
# 83               13.09.2009  9789548226592  15496       14719      52
# 84               20.10.2009  9789548226738   8041        7100      25
# 85               17.09.2010  9789544100124   3769        2964      53
# 86               17.12.2010  9789548226912    608         436       1
# 87               24.12.2010  9789548226837   1189         616       0
# 88               09.01.2011  9789544100148   2311        1245      15
# 89               09.01.2011  9789544100131   1943         677       0
# 90               12.03.2011  9789548226424   1952        1567       4
# 91               14.03.2011  9789548226776   1329         644       5
# 92               25.03.2011  9789544100155   1013         447       5
# 93               29.03.2011  9789547580015   2993        2170      11
# 94               06.04.2011  9789548226820    743         543       0
# 95               09.06.2011  9789544100056  10633        9419      33
# 96               08.11.2011  9789544100179   2349        1163       4
# 97               21.01.2012  9789544100193    445         303       0
# 98               22.05.2012  9789544100247   1444        1005      20
# 99               04.08.2012  9789544100230   1175         828       4
# 100              25.01.2013  9789544100278   2859        2688       4
# 101              02.04.2013  9789544100285    255         227       1
# 102              05.05.2014  9789544100292   1421        1393      17
# 103              27.01.2015  9789544100315    498         465      11
# 104              15.05.2016  9789544100322    266         254       1
# 105              12.07.2016  9789544100308     88          85       0
# 106              12.10.2016  9789663726700     94          94       0
#
#      clicks2   ctr  pagesViewed
# 0         72  2,3%       179623
# 1         26  0,2%       187030
# 2         32  0,3%       194957
# 3         22  0,6%        46428
# 4         18  0,5%        77310
# 5         14  0,7%        39015
# 6         16  0,9%        27113
# 7          2  0,1%        17267
# 8         17  0,2%       185101
# 9         30  0,3%       203411
# 10        31  0,8%        43997
# 11         0  0,0%        11174
# 12         5  0,2%        47305
# 13         1  0,1%         8584
# 14         5  0,3%        14675
# 15         9  0,3%        66220
# 16         2  0,0%        21665
# 17        17  0,5%        63599
# 18         8  0,5%        29103
# 19         3  0,1%        30779
# 20         0  0,0%        22084
# 21        17  0,2%       149776
# 22        17  0,2%       149776
# 23         1  0,1%         7978
# 24         0  0,0%        11932
# 25        12  0,1%       140183
# 26         2  0,1%        50884
# 27         2  0,1%         4534
# 28        13  0,3%        42267
# 29         4  0,3%        10266
# ..       ...   ...          ...
# 77       110  0,3%       638233
# 78         1  0,1%         6702
# 79         2  0,1%        35393
# 80         2  0,3%         2397
# 81         1  0,1%         2383
# 82         2  0,0%        34025
# 83        35  0,2%       317939
# 84        23  0,3%       232313
# 85        48  1,3%        63979
# 86         1  0,2%         3068
# 87         0  0,0%         5076
# 88        10  0,4%        18265
# 89         0  0,0%         3687
# 90         1  0,1%        21519
# 91         3  0,2%         4915
# 92         3  0,3%         4480
# 93         7  0,2%        34252
# 94         0  0,0%         3555
# 95        28  0,3%       130407
# 96         4  0,2%         7964
# 97         0  0,0%         4679
# 98        12  0,8%        11327
# 99         2  0,2%         9804
# 100        3  0,1%        46646
# 101        1  0,4%         3348
# 102       14  1,0%        14364
# 103        7  1,4%         4345
# 104        1  0,4%         3466
# 105        0  0,0%         2977
# 106        0  0,0%          922
#
# [107 rows x 13 columns]

# %%
def generateDiv(s):
    title = u'<div> <a href="http://books.google.com/books?{}&printsec=frontcover"><b>"{}"</b></a>'.format(s['id'], s['title'])
    auth = u' {} '.format(s.authors)
    inPrint = u'(книжно издание {}; електронно издание {})'.format(s.date_print, s.date_ebook)
    stats = u' - {} читатели, прочели {} страници.'.format(s['bookVisits'].astype(int), s['pagesViewed'].astype(int))
    div2 = u'</div>'
    #(книжно издание 20.10.2008; електронно издание 29.09.2008)
    return title + auth + inPrint + stats + div2
    
def getAuthor(s):
    index = s.find('[') - 1
    return s[:index]

# %%
print generateDiv(b.iloc[1,:])
# Out:
# <div> <a href="http://books.google.com/books?id=AxzRmIQjCbgC&printsec=frontcover"><b>"Любов на живо"</b></a> на Александър Хараланов (книжно издание 20.10.2008; електронно издание 29.09.2008) - 11581 читатели, прочели 187030 страници.</div>

# %%
intro1 = u'<b>Общо <i>(до 20 март 2017 г.)</i> '
intro2 = u'<a href="http://books.google.com/books?q=inpublisher:fliorir">електронните книги на издателство "Фльорир"</a> '
intro3 = u'са посетени от {:d} читатели, прочели {} страници.</b>\n'.format(b['bookVisits'].sum(), b['pagesViewed'].sum())
intro4 = u'<div><span style="color: red;"><b>Посещаемост на електронните издания на книги на издателство "Фльорир":</b></span></div>\n\n'
intro = intro1 + intro2 + intro3 + intro4
ending = u'<span style="color: #33cc00;"><b><i>Частично позициониране на страницата - на всеки 30 дни.</i></b></span>'

with open("Output.txt", "a") as f:
    f.write((intro).encode('utf8'))
    for i in range(len(b)):
        f.write(generateDiv(b.iloc[i]).encode('utf8'))
        f.write(u'\n\n')
    f.write(ending.encode('utf8'))

# %% [raw]
# from bs4 import BeautifulSoup
# import requests
#
# html_page = "https://play.google.com/books/publish/a/429709881475690409/downloadTrafficReport?f.req=%5B%5Bnull%2C2016%2C4%2C1%5D%2C%5Bnull%2C2016%2C7%2C1%5D%2C2%5D&hl=bg&token="
#
# r = requests.get(html_page)

# %% [raw]
# r.content

# %% [raw]
# r.text
